# %%
import pandas as pd
from rdkit.Chem.PandasTools import AddMoleculeColumnToFrame

# %%
df = pd.read_csv("PD1_inhibitor_dataset.csv")

# %%
AddMoleculeColumnToFrame(df, "smiles", "structural_formula")

# %%
df[["compound_id", "structural_formula", "patent_no"]]
# Out:
#     compound_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
